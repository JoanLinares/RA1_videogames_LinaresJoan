# %% [markdown]
# # 📊 RA1 - Análisis de Videojuegos con PySpark
#
# ## Fase 2: Procesamiento con PySpark
#
# Objetivo: procesar el dataset de videojuegos usando PySpark, aplicando transformaciones distribuidas y mostrar los resultados.

# %% [markdown]
# ### 1. Crear SparkSession
# Configuramos PySpark y creamos la sesión de Spark.

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import (
    col, count, avg, sum, when, round as spark_round,
    regexp_extract, trim
)
from pyspark.sql.types import DoubleType
import os
import warnings

warnings.filterwarnings("ignore")

# Crear SparkSession
spark = (
    SparkSession.builder
    .appName("VideoGames Analysis")
    .getOrCreate()
)

print("Versión de Spark:", spark.version)
print("SparkSession creada correctamente ✅")
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/12/10 16:21:40 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Versión de Spark: 3.5.0
# SparkSession creada correctamente ✅

# %% [markdown]
# ### 2. Cargar el dataset
# Cargamos el dataset original o limpio con rutas robustas.

# %%
# Posibles rutas donde podrías tener el CSV
possible_paths = [
    "videogames.csv",
    "../videogames.csv",
    "../data/videogames.csv",
    "/mnt/data/videogames.csv"  # ruta típica en entornos de prácticas
]

csv_path = None
for p in possible_paths:
    if os.path.exists(p):
        csv_path = p
        break

if csv_path is None:
    raise FileNotFoundError(
        f"No se encontró 'videogames.csv' en ninguna de estas rutas:\n{possible_paths}"
    )

# Cargar dataset con inferencia de esquema
df_spark = (
    spark.read
    .option("header", True)
    .option("inferSchema", True)
    .csv(csv_path)
)

print("Ruta cargada:", csv_path)
print("Número de filas:", df_spark.count())
print("Número de columnas:", len(df_spark.columns))

df_spark.printSchema()
df_spark.show(5, truncate=False)
# Out:
# Ruta cargada: ../data/videogames.csv
# 25/12/10 16:21:53 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors
# Número de filas: 10000
# Número de columnas: 21
# root
#  |-- name: string (nullable = true)
#  |-- genre: string (nullable = true)
#  |-- cost: string (nullable = true)
#  |-- platform: string (nullable = true)
#  |-- popularity: string (nullable = true)
#  |-- pegi: string (nullable = true)
#  |-- year: string (nullable = true)
#  |-- developer: string (nullable = true)
#  |-- publisher: string (nullable = true)
#  |-- region: string (nullable = true)
#  |-- mode: string (nullable = true)
#  |-- engine: string (nullable = true)
#  |-- award: string (nullable = true)
#  |-- dlc_support: string (nullable = true)
#  |-- language: string (nullable = true)
#  |-- metascore: string (nullable = true)
#  |-- user_score: string (nullable = true)
#  |-- reviews: string (nullable = true)
#  |-- rating_source: string (nullable = true)
#  |-- copies_sold_millions: string (nullable = true)
#  |-- revenue_millions_usd: string (nullable = true)
#
# +-------------------+-------+-----+--------+-----------------+----+----+---------+------------+-------+-------------+-------------+-----------+-----------+--------+---------+----------+-----------------+-------------+--------------------+--------------------+
# |name               |genre  |cost |platform|popularity       |pegi|year|developer|publisher   |region |mode         |engine       |award      |dlc_support|language|metascore|user_score|reviews          |rating_source|copies_sold_millions|revenue_millions_usd|
# +-------------------+-------+-----+--------+-----------------+----+----+---------+------------+-------+-------------+-------------+-----------+-----------+--------+---------+----------+-----------------+-------------+--------------------+--------------------+
# |Super Mario Odyssey|Action |74.45|Mobile  |56               |7+  |2011|Capcom   |Square Enix |?      |Multiplayer  |CryEngine    |Indie Award|Unknown    |JP      |?        |?         |9.388708962265735|Metacritic   |41.93               |?                   |
# |God of War         |RPG    |0    |Mobile  |?                |7+  |2023|Rockstar |Nintendo    |Global |Online       |Unity        |?          |Y          |DE      |98.1     |8.4       |?                |IGN          |1.5M                |N/A                 |
# |Persona 5 Royal    |Shooter|Free |PS      |64               |12  |2020|nintendo |Square Enix |NA     |Single-player|Custom Engine|GotY       |Y          |DE      |31.7     |2.6       |?                |IGN          |25.08               |889.0               |
# |NBA 2K24           |Puzzle |N/A  |Mobile  |972.7113240416031|RP  |2017|Sony     |Square Enix |Global |Single-player|Custom Engine|NONE       |?          |ES      |80/100   |N/A       |?                |OpenCritic   |N/A                 |$500M               |
# |Overwatch          |?      |33.4 |PC      |612.6268621737502|18+ |2015|Nintendo |Bandai Namco|NA/EU  |Multiplayer  |Custom       |Indie Award|Unknown    |IT      |36.0     |2.3       |N/A              |Metacritic   |N/A                 |$1B                 |
# +-------------------+-------+-----+--------+-----------------+----+----+---------+------------+-------+-------------+-------------+-----------+-----------+--------+---------+----------+-----------------+-------------+--------------------+--------------------+
# only showing top 5 rows

# %% [markdown]
# ### 3. Transformación 1: Selección y filtrado de columnas
# Seleccionamos columnas relevantes y filtramos datos válidos.

# %%
# Columnas que nos interesan para el análisis
cols_basic = [
    "name",              # ojo: en el CSV se llama 'name', no 'title'
    "platform",
    "genre",
    "metascore",
    "user_score",
    "copies_sold_millions",
    "revenue_millions_usd"
]

df_selected = df_spark.select(*cols_basic)

# Crear columnas numéricas a partir de texto:
# - metascore_num: extrae el número inicial (ej. '80/100' -> 80, '47.7' -> 47.7)
# - copies_sold_millions_num: extrae el primer número (ej. '1.5M' -> 1.5, '30M' -> 30)
df_numeric = (
    df_selected
    .withColumn(
        "metascore_num",
        regexp_extract(
            trim(col("metascore").cast("string")),
            r'^\d+(\.\d+)?',
            0
        ).cast(DoubleType())
    )
    .withColumn(
        "copies_sold_millions_num",
        regexp_extract(
            trim(col("copies_sold_millions").cast("string")),
            r'([0-9]*\.?[0-9]+)',
            1
        ).cast(DoubleType())
    )
)

# Filtramos filas con valores numéricos válidos
df_filtered = (
    df_numeric
    .filter(col("metascore_num").isNotNull())
    .filter(col("copies_sold_millions_num").isNotNull())
)

print("Filas después de selección y filtrado:", df_filtered.count())
df_filtered.show(10, truncate=False)
# Out:
# Filas después de selección y filtrado: 2983
# +-------------------------+---------------+----------+---------+----------+--------------------+--------------------+-------------+------------------------+
# |name                     |platform       |genre     |metascore|user_score|copies_sold_millions|revenue_millions_usd|metascore_num|copies_sold_millions_num|
# +-------------------------+---------------+----------+---------+----------+--------------------+--------------------+-------------+------------------------+
# |God of War               |Mobile         |RPG       |98.1     |8.4       |1.5M                |N/A                 |98.1         |1.5                     |
# |Persona 5 Royal          |PS             |Shooter   |31.7     |2.6       |25.08               |889.0               |31.7         |25.08                   |
# |Untitled Project         |Nintendo Switch|Unknown   |80/100   |?         |30M                 |?                   |80.0         |30.0                    |
# |Valorant                 |Switch         |Simulation|84.8     |3.1       |1.5M                |?                   |84.8         |1.5                     |
# |N/A                      |PC             |?         |80/100   |?         |46.29               |$500M               |80.0         |46.29                   |
# |Dark Souls III           |PC             |RPG       |80/100   |9/10      |30M                 |$1B                 |80.0         |30.0                    |
# |God of War               |PlayStation    |?         |55.6     |0.2       |32.58               |?                   |55.6         |32.58                   |
# |Overwatch                |Mobile         |Indie     |80/100   |5.0       |1.5M                |82.1                |80.0         |1.5                     |
# |The Sims 4               |Switch         |Indie     |80/100   |?         |15.58               |N/A                 |80.0         |15.58                   |
# |Sekiro: Shadows Die Twice|Mobile         |Simulation|47.5     |N/A       |15.18               |N/A                 |47.5         |15.18                   |
# +-------------------------+---------------+----------+---------+----------+--------------------+--------------------+-------------+------------------------+
# only showing top 10 rows

# %% [markdown]
# ### 4. Transformación 2: Agregación por género
# Calculamos estadísticas agrupadas por género de videojuego.

# %%
# Agregación por género: nº de juegos, metascore medio y ventas totales
df_by_genre = (
    df_filtered
    .groupBy("genre")
    .agg(
        count("*").alias("num_juegos"),
        spark_round(avg("metascore_num"), 2).alias("metascore_medio"),
        spark_round(sum("copies_sold_millions_num"), 2).alias("ventas_totales_millones")
    )
    .orderBy(col("ventas_totales_millones").desc())
)

print("Estadísticas agregadas por género:")
df_by_genre.show(20, truncate=False)
# Out:
# Estadísticas agregadas por género:
# +----------+----------+---------------+-----------------------+
# |genre     |num_juegos|metascore_medio|ventas_totales_millones|
# +----------+----------+---------------+-----------------------+
# |Adventure |231       |71.62          |4684.0                 |
# |Unknown   |231       |70.53          |4379.97                |
# |RPG       |214       |70.7           |4310.9                 |
# |?         |219       |72.68          |4255.91                |
# |RPG       |219       |70.59          |4221.08                |
# |Puzzle    |213       |69.8           |4094.84                |
# |Indie     |211       |70.88          |3971.67                |
# |Sports    |236       |68.34          |3970.57                |
# |Simulation|205       |72.19          |3917.29                |
# |action    |200       |69.66          |3898.19                |
# |Racing    |194       |70.12          |3852.02                |
# |Shooter   |210       |69.22          |3838.77                |
# |Action    |200       |70.14          |3646.14                |
# |Strategy  |200       |69.84          |3627.51                |
# +----------+----------+---------------+-----------------------+

# %% [markdown]
# ### 5. Transformación 3: Creación de nuevas columnas
# Añadimos columnas calculadas para análisis adicionales.

# %%
df_with_new_cols = (
    df_filtered
    .withColumn(
        "categoria_ventas",
        when(col("copies_sold_millions_num") >= 5, "Alto")
        .when(col("copies_sold_millions_num") >= 1, "Medio")
        .otherwise("Bajo")
    )
    .withColumn(
        "categoria_calidad",
        when(col("metascore_num") >= 85, "Excelente")
        .when(col("metascore_num") >= 70, "Buena")
        .when(col("metascore_num") >= 50, "Regular")
        .otherwise("Mala")
    )
)

print("Ejemplo de nuevas columnas creadas:")
df_with_new_cols.select(
    "name", "platform", "genre",
    "metascore_num", "copies_sold_millions_num",
    "categoria_ventas", "categoria_calidad"
).show(20, truncate=False)
# Out:
# Ejemplo de nuevas columnas creadas:
# +---------------------------------------+---------------+----------+-------------+------------------------+----------------+-----------------+
# |name                                   |platform       |genre     |metascore_num|copies_sold_millions_num|categoria_ventas|categoria_calidad|
# +---------------------------------------+---------------+----------+-------------+------------------------+----------------+-----------------+
# |God of War                             |Mobile         |RPG       |98.1         |1.5                     |Medio           |Excelente        |
# |Persona 5 Royal                        |PS             |Shooter   |31.7         |25.08                   |Alto            |Mala             |
# |Untitled Project                       |Nintendo Switch|Unknown   |80.0         |30.0                    |Alto            |Buena            |
# |Valorant                               |Switch         |Simulation|84.8         |1.5                     |Medio           |Buena            |
# |N/A                                    |PC             |?         |80.0         |46.29                   |Alto            |Buena            |
# |Dark Souls III                         |PC             |RPG       |80.0         |30.0                    |Alto            |Buena            |
# |God of War                             |PlayStation    |?         |55.6         |32.58                   |Alto            |Regular          |
# |Overwatch                              |Mobile         |Indie     |80.0         |1.5                     |Medio           |Buena            |
# |The Sims 4                             |Switch         |Indie     |80.0         |15.58                   |Alto            |Buena            |
# |Sekiro: Shadows Die Twice              |Mobile         |Simulation|47.5         |15.18                   |Alto            |Mala             |
# |N/A                                    |PlayStation    |Action    |80.0         |36.85                   |Alto            |Buena            |
# |The Witcher 3: Wild Hunt               |PlayStation    |Simulation|57.1         |1.5                     |Medio           |Regular          |
# |Overwatch                              |Nintendo Switch|Action    |79.3         |18.31                   |Alto            |Buena            |
# |Final Fantasy VII Remake               |Mobile         |Strategy  |64.8         |25.92                   |Alto            |Regular          |
# |League of Legends                      |XBOX           |?         |99.9         |30.0                    |Alto            |Excelente        |
# |The Legend of Zelda: Breath of the Wild|PlayStation    |Sports    |80.0         |1.5                     |Medio           |Buena            |
# |Valorant                               |PC             |Puzzle    |80.0         |35.64                   |Alto            |Buena            |
# |Apex Legends                           |XBOX           |RPG       |65.4         |47.05                   |Alto            |Regular          |
# |FIFA 23                                |PlayStation    |Indie     |28.5         |30.0                    |Alto            |Mala             |
# |Overwatch                              |Nintendo Switch|RPG       |67.2         |47.49                   |Alto            |Regular          |
# +---------------------------------------+---------------+----------+-------------+------------------------+----------------+-----------------+
# only showing top 20 rows

# %% [markdown]
# ### 6. Transformación 4: Análisis por plataforma y género (Join simulado)
# Cruzamos información de plataforma y género para análisis detallado.

# %%
# Agregación por plataforma
df_platform_stats = (
    df_with_new_cols
    .groupBy("platform")
    .agg(
        count("*").alias("num_juegos_plataforma"),
        spark_round(avg("metascore_num"), 2).alias("metascore_medio_plataforma"),
        spark_round(sum("copies_sold_millions_num"), 2).alias("ventas_totales_plataforma")
    )
)

print("Estadísticas por plataforma:")
df_platform_stats.show(truncate=False)

# JOIN: añadimos las estadísticas de plataforma a cada juego
df_joined = (
    df_with_new_cols
    .join(df_platform_stats, on="platform", how="left")
)

print("Ejemplo de análisis cruzado (juego + stats de su plataforma):")
df_joined.select(
    "name", "platform", "genre",
    "metascore_num", "copies_sold_millions_num",
    "num_juegos_plataforma",
    "metascore_medio_plataforma",
    "ventas_totales_plataforma"
).show(20, truncate=False)

# Opcional: cache para reutilizar en otras fases
df_joined.cache()
# Out:
# Estadísticas por plataforma:
# +---------------+---------------------+--------------------------+-------------------------+
# |platform       |num_juegos_plataforma|metascore_medio_plataforma|ventas_totales_plataforma|
# +---------------+---------------------+--------------------------+-------------------------+
# |PC             |325                  |71.43                     |6067.13                  |
# |PS             |349                  |70.55                     |7103.83                  |
# |XBOX           |323                  |71.62                     |6334.43                  |
# |PlayStation    |327                  |70.28                     |5770.74                  |
# |Nintendo Switch|375                  |69.93                     |7033.16                  |
# |Switch         |312                  |70.74                     |5935.08                  |
# |Xbox           |295                  |70.1                      |5559.84                  |
# |Mobile         |342                  |69.44                     |6370.95                  |
# |pc             |335                  |70.11                     |6493.7                   |
# +---------------+---------------------+--------------------------+-------------------------+
#
# Ejemplo de análisis cruzado (juego + stats de su plataforma):
# +---------------------------------------+---------------+----------+-------------+------------------------+---------------------+--------------------------+-------------------------+
# |name                                   |platform       |genre     |metascore_num|copies_sold_millions_num|num_juegos_plataforma|metascore_medio_plataforma|ventas_totales_plataforma|
# +---------------------------------------+---------------+----------+-------------+------------------------+---------------------+--------------------------+-------------------------+
# |God of War                             |Mobile         |RPG       |98.1         |1.5                     |342                  |69.44                     |6370.95                  |
# |Persona 5 Royal                        |PS             |Shooter   |31.7         |25.08                   |349                  |70.55                     |7103.83                  |
# |Untitled Project                       |Nintendo Switch|Unknown   |80.0         |30.0                    |375                  |69.93                     |7033.16                  |
# |Valorant                               |Switch         |Simulation|84.8         |1.5                     |312                  |70.74                     |5935.08                  |
# |N/A                                    |PC             |?         |80.0         |46.29                   |325                  |71.43                     |6067.13                  |
# |Dark Souls III                         |PC             |RPG       |80.0         |30.0                    |325                  |71.43                     |6067.13                  |
# |God of War                             |PlayStation    |?         |55.6         |32.58                   |327                  |70.28                     |5770.74                  |
# |Overwatch                              |Mobile         |Indie     |80.0         |1.5                     |342                  |69.44                     |6370.95                  |
# |The Sims 4                             |Switch         |Indie     |80.0         |15.58                   |312                  |70.74                     |5935.08                  |
# |Sekiro: Shadows Die Twice              |Mobile         |Simulation|47.5         |15.18                   |342                  |69.44                     |6370.95                  |
# |N/A                                    |PlayStation    |Action    |80.0         |36.85                   |327                  |70.28                     |5770.74                  |
# |The Witcher 3: Wild Hunt               |PlayStation    |Simulation|57.1         |1.5                     |327                  |70.28                     |5770.74                  |
# |Overwatch                              |Nintendo Switch|Action    |79.3         |18.31                   |375                  |69.93                     |7033.16                  |
# |Final Fantasy VII Remake               |Mobile         |Strategy  |64.8         |25.92                   |342                  |69.44                     |6370.95                  |
# |League of Legends                      |XBOX           |?         |99.9         |30.0                    |323                  |71.62                     |6334.43                  |
# |The Legend of Zelda: Breath of the Wild|PlayStation    |Sports    |80.0         |1.5                     |327                  |70.28                     |5770.74                  |
# |Valorant                               |PC             |Puzzle    |80.0         |35.64                   |325                  |71.43                     |6067.13                  |
# |Apex Legends                           |XBOX           |RPG       |65.4         |47.05                   |323                  |71.62                     |6334.43                  |
# |FIFA 23                                |PlayStation    |Indie     |28.5         |30.0                    |327                  |70.28                     |5770.74                  |
# |Overwatch                              |Nintendo Switch|RPG       |67.2         |47.49                   |375                  |69.93                     |7033.16                  |
# +---------------------------------------+---------------+----------+-------------+------------------------+---------------------+--------------------------+-------------------------+
# only showing top 20 rows
# DataFrame[platform: string, name: string, genre: string, metascore: string, user_score: string, copies_sold_millions: string, revenue_millions_usd: string, metascore_num: double, copies_sold_millions_num: double, categoria_ventas: string, categoria_calidad: string, num_juegos_plataforma: bigint, metascore_medio_plataforma: double, ventas_totales_plataforma: double]

# %% [markdown]
# ---
#
# ## Proceso ETL con PySpark
#
# Objetivo: Extraer, Transformar y Cargar (ETL) los datos procesados a una base de datos SQLite con un modelo dimensional (1 tabla de hechos + 2 tablas de dimensiones).

# %% [markdown]
# ### 7. EXTRACCIÓN (E)
# Reutilizamos el DataFrame transformado de las fases anteriores.

# %%
# Ya tenemos df_joined con todos los datos transformados
# Aseguramos que el DataFrame esté en caché para optimizar
df_etl = df_joined.cache()

print("="*70)
print("EXTRACCIÓN - Dataset transformado cargado")
print("="*70)
print(f"Registros: {df_etl.count()}")
print(f"Columnas: {len(df_etl.columns)}")
print("\nEsquema del DataFrame:")
df_etl.printSchema()
# Out:
# 25/12/10 18:11:11 WARN CacheManager: Asked to cache already cached data.
# ======================================================================
# EXTRACCIÓN - Dataset transformado cargado
# ======================================================================
# Registros: 2983
# Columnas: 14
#
# Esquema del DataFrame:
# root
#  |-- platform: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- genre: string (nullable = true)
#  |-- metascore: string (nullable = true)
#  |-- user_score: string (nullable = true)
#  |-- copies_sold_millions: string (nullable = true)
#  |-- revenue_millions_usd: string (nullable = true)
#  |-- metascore_num: double (nullable = true)
#  |-- copies_sold_millions_num: double (nullable = true)
#  |-- categoria_ventas: string (nullable = false)
#  |-- categoria_calidad: string (nullable = false)
#  |-- num_juegos_plataforma: long (nullable = true)
#  |-- metascore_medio_plataforma: double (nullable = true)
#  |-- ventas_totales_plataforma: double (nullable = true)

# %% [markdown]
# ### 8. TRANSFORMACIÓN (T) - Modelo Dimensional
# Creamos un modelo estrella con 1 tabla de hechos y 2 tablas de dimensiones.

# %%
from pyspark.sql.functions import row_number
from pyspark.sql.window import Window

print("="*70)
print("TRANSFORMACIÓN - Creando modelo dimensional")
print("="*70)

# Ventanas para generar IDs secuenciales
w_genre = Window.orderBy("genre")
w_platform = Window.orderBy("platform")
w_fact = Window.orderBy("name", "genre", "platform")

# ==============================================================
# DIMENSIÓN 1: dim_genre (Dimensión de Género)
# ==============================================================
dim_genre = (
    df_etl
    .select("genre")
    .distinct()
    .withColumn("genre_id", row_number().over(w_genre))
    .select("genre_id", "genre")
)

print("\n📊 Dimensión 1: dim_genre")
print(f"Registros: {dim_genre.count()}")
dim_genre.show(10, truncate=False)

# ==============================================================
# DIMENSIÓN 2: dim_platform (Dimensión de Plataforma)
# ==============================================================
dim_platform = (
    df_etl
    .select("platform")
    .distinct()
    .withColumn("platform_id", row_number().over(w_platform))
    .select("platform_id", "platform")
)

print("\n📊 Dimensión 2: dim_platform")
print(f"Registros: {dim_platform.count()}")
dim_platform.show(10, truncate=False)

# ==============================================================
# TABLA DE HECHOS: fact_videogames
# ==============================================================
fact_videogames = (
    df_etl
    .join(dim_genre, on="genre", how="left")
    .join(dim_platform, on="platform", how="left")
    .withColumn("fact_id", row_number().over(w_fact))
    .select(
        "fact_id",
        "name",
        "genre_id",
        "platform_id",
        "metascore_num",
        "copies_sold_millions_num",
        "categoria_ventas",
        "categoria_calidad",
        "num_juegos_plataforma",
        "metascore_medio_plataforma",
        "ventas_totales_plataforma"
    )
)

print("\n📊 Tabla de Hechos: fact_videogames")
print(f"Registros: {fact_videogames.count()}")
fact_videogames.show(10, truncate=False)

print("\n" + "="*70)
print("Modelo dimensional creado exitosamente:")
print(f"  - dim_genre: {dim_genre.count()} registros")
print(f"  - dim_platform: {dim_platform.count()} registros")
print(f"  - fact_videogames: {fact_videogames.count()} registros")
print("="*70)
# Out:
# ======================================================================
# TRANSFORMACIÓN - Creando modelo dimensional
# ======================================================================
#
# 📊 Dimensión 1: dim_genre
# Registros: 14
# 25/12/10 18:11:19 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:19 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:19 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:19 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:19 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:19 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:19 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:19 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# +--------+----------+
# |genre_id|genre     |
# +--------+----------+
# |1       |?         |
# |2       |Action    |
# |3       |Adventure |
# |4       |Indie     |
# |5       |Puzzle    |
# |6       |RPG       |
# |7       |RPG       |
# |8       |Racing    |
# |9       |Shooter   |
# |10      |Simulation|
# +--------+----------+
# only showing top 10 rows
#
#
# 📊 Dimensión 2: dim_platform
# Registros: 9
# +-----------+---------------+
# |platform_id|platform       |
# +-----------+---------------+
# |1          |Mobile         |
# |2          |Nintendo Switch|
# |3          |PC             |
# |4          |PS             |
# |5          |PlayStation    |
# |6          |Switch         |
# |7          |XBOX           |
# |8          |Xbox           |
# |9          |pc             |
# +-----------+---------------+
# 25/12/10 18:11:19 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:19 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:19 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:19 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:19 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:19 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:19 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:19 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 📊 Tabla de Hechos: fact_videogames
# Registros: 2983
# 25/12/10 18:11:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:11:20 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# +-------+----+--------+-----------+-------------+------------------------+----------------+-----------------+---------------------+--------------------------+-------------------------+
# |fact_id|name|genre_id|platform_id|metascore_num|copies_sold_millions_num|categoria_ventas|categoria_calidad|num_juegos_plataforma|metascore_medio_plataforma|ventas_totales_plataforma|
# +-------+----+--------+-----------+-------------+------------------------+----------------+-----------------+---------------------+--------------------------+-------------------------+
# |1      |    |1       |1          |43.2         |23.52                   |Alto            |Mala             |342                  |69.44                     |6370.95                  |
# |2      |    |1       |2          |80.0         |30.0                    |Alto            |Buena            |375                  |69.93                     |7033.16                  |
# |3      |    |1       |2          |48.5         |1.5                     |Medio           |Mala             |375                  |69.93                     |7033.16                  |
# |4      |    |1       |6          |80.0         |1.5                     |Medio           |Buena            |312                  |70.74                     |5935.08                  |
# |5      |    |1       |7          |69.3         |14.78                   |Alto            |Regular          |323                  |71.62                     |6334.43                  |
# |6      |    |2       |1          |80.0         |30.0                    |Alto            |Buena            |342                  |69.44                     |6370.95                  |
# |7      |    |2       |3          |93.9         |32.51                   |Alto            |Excelente        |325                  |71.43                     |6067.13                  |
# |8      |    |2       |4          |80.0         |30.0                    |Alto            |Buena            |349                  |70.55                     |7103.83                  |
# |9      |    |2       |4          |80.0         |30.0                    |Alto            |Buena            |349                  |70.55                     |7103.83                  |
# |10     |    |2       |7          |80.0         |30.0                    |Alto            |Buena            |323                  |71.62                     |6334.43                  |
# +-------+----+--------+-----------+-------------+------------------------+----------------+-----------------+---------------------+--------------------------+-------------------------+
# only showing top 10 rows
#
#
# ======================================================================
# Modelo dimensional creado exitosamente:
#   - dim_genre: 14 registros
#   - dim_platform: 9 registros
#   - fact_videogames: 2983 registros
# ======================================================================

# %% [markdown]
# ### 9. CARGA (L)
# Guardamos el modelo dimensional en SQLite (warehouse_pyspark.db) en el directorio warehouse.

# %%
import sqlite3
from pathlib import Path

# Determinar la ruta del warehouse
warehouse_paths = [
    '../warehouse/warehouse_pyspark.db',    # ejecución local
    '/app/warehouse/warehouse_pyspark.db'   # ejecución en contenedor
]

# Crear directorio si no existe
for path in warehouse_paths:
    warehouse_dir = Path(path).parent
    if warehouse_dir.exists() or str(warehouse_dir).startswith('..'):
        db_path = path
        warehouse_dir.mkdir(parents=True, exist_ok=True)
        break
else:
    db_path = warehouse_paths[0]
    Path(db_path).parent.mkdir(parents=True, exist_ok=True)

print("="*70)
print("CARGA - Guardando modelo dimensional en SQLite")
print("="*70)
print(f"Base de datos: {db_path}\n")

# Convertir DataFrames de PySpark a Pandas para cargar en SQLite
dim_genre_pd = dim_genre.toPandas()
dim_platform_pd = dim_platform.toPandas()
fact_videogames_pd = fact_videogames.toPandas()

# Crear conexión a SQLite
conn = sqlite3.connect(db_path)

# Cargar dimensiones
dim_genre_pd.to_sql('dim_genre', conn, if_exists='replace', index=False)
print(f"✓ Dimensión 'dim_genre' cargada: {len(dim_genre_pd)} registros")

dim_platform_pd.to_sql('dim_platform', conn, if_exists='replace', index=False)
print(f"✓ Dimensión 'dim_platform' cargada: {len(dim_platform_pd)} registros")

# Cargar tabla de hechos
fact_videogames_pd.to_sql('fact_videogames', conn, if_exists='replace', index=False)
print(f"✓ Tabla de hechos 'fact_videogames' cargada: {len(fact_videogames_pd)} registros")

# Cerrar conexión
conn.close()

print("\n" + "="*70)
print("PROCESO ETL CON PYSPARK COMPLETADO CON ÉXITO")
print("="*70)
print(f"Base de datos creada: {db_path}")
print("Modelo dimensional:")
print("  - dim_genre (dimensión)")
print("  - dim_platform (dimensión)")
print("  - fact_videogames (hechos)")
print("="*70)
# Out:
# ======================================================================
# CARGA - Guardando modelo dimensional en SQLite
# ======================================================================
# Base de datos: ../warehouse/warehouse_pyspark.db
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:08 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:09 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 25/12/10 18:12:09 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# ✓ Dimensión 'dim_genre' cargada: 14 registros
# ✓ Dimensión 'dim_platform' cargada: 9 registros
# ✓ Tabla de hechos 'fact_videogames' cargada: 2983 registros
#
# ======================================================================
# PROCESO ETL CON PYSPARK COMPLETADO CON ÉXITO
# ======================================================================
# Base de datos creada: ../warehouse/warehouse_pyspark.db
# Modelo dimensional:
#   - dim_genre (dimensión)
#   - dim_platform (dimensión)
#   - fact_videogames (hechos)
# ======================================================================

# %% [markdown]
# ### 10. Verificación del modelo dimensional
# Consultamos la base de datos para verificar el modelo estrella cargado.

# %%
import pandas as pd

# Conectar a la base de datos
conn = sqlite3.connect(db_path)

# Listar todas las tablas
query_tables = "SELECT name FROM sqlite_master WHERE type='table';"
tables = pd.read_sql(query_tables, conn)
print("Tablas en la base de datos:")
print(tables)

# Verificar registros en cada tabla
print("\n" + "="*70)
print("CONTEO DE REGISTROS POR TABLA")
print("="*70)

for table_name in tables['name']:
    query = f"SELECT COUNT(*) as count FROM {table_name};"
    result = pd.read_sql(query, conn)
    print(f"{table_name}: {result['count'].iloc[0]} registros")

# Mostrar muestra de cada tabla
print("\n" + "="*70)
print("MUESTRA DE dim_genre")
print("="*70)
query_genre = "SELECT * FROM dim_genre LIMIT 10;"
sample_genre = pd.read_sql(query_genre, conn)
print(sample_genre)

print("\n" + "="*70)
print("MUESTRA DE dim_platform")
print("="*70)
query_platform = "SELECT * FROM dim_platform LIMIT 10;"
sample_platform = pd.read_sql(query_platform, conn)
print(sample_platform)

print("\n" + "="*70)
print("MUESTRA DE fact_videogames")
print("="*70)
query_fact = "SELECT * FROM fact_videogames LIMIT 10;"
sample_fact = pd.read_sql(query_fact, conn)
print(sample_fact)

# Ejemplo de consulta JOIN para verificar el modelo estrella
print("\n" + "="*70)
print("CONSULTA JOIN - Análisis por género y plataforma")
print("="*70)
query_join = """
SELECT 
    g.genre,
    p.platform,
    COUNT(*) as num_juegos,
    ROUND(AVG(f.metascore_num), 2) as metascore_promedio,
    ROUND(SUM(f.copies_sold_millions_num), 2) as ventas_totales
FROM fact_videogames f
JOIN dim_genre g ON f.genre_id = g.genre_id
JOIN dim_platform p ON f.platform_id = p.platform_id
GROUP BY g.genre, p.platform
ORDER BY ventas_totales DESC
LIMIT 15;
"""
result_join = pd.read_sql(query_join, conn)
print(result_join)

# Cerrar conexión
conn.close()

print("\n✅ Verificación completada. Modelo dimensional funcionando correctamente.")
print("✅ ETL con PySpark finalizado exitosamente.")
# Out:
# Tablas en la base de datos:
#               name
# 0        dim_genre
# 1     dim_platform
# 2  fact_videogames
#
# ======================================================================
# CONTEO DE REGISTROS POR TABLA
# ======================================================================
# dim_genre: 14 registros
# dim_platform: 9 registros
# fact_videogames: 2983 registros
#
# ======================================================================
# MUESTRA DE dim_genre
# ======================================================================
#    genre_id       genre
# 0         1           ?
# 1         2      Action
# 2         3   Adventure
# 3         4       Indie
# 4         5      Puzzle
# 5         6         RPG
# 6         7        RPG
# 7         8      Racing
# 8         9     Shooter
# 9        10  Simulation
#
# ======================================================================
# MUESTRA DE dim_platform
# ======================================================================
#    platform_id         platform
# 0            1           Mobile
# 1            2  Nintendo Switch
# 2            3               PC
# 3            4               PS
# 4            5      PlayStation
# 5            6          Switch
# 6            7             XBOX
# 7            8             Xbox
# 8            9               pc
#
# ======================================================================
# MUESTRA DE fact_videogames
# ======================================================================
#    fact_id name  genre_id  platform_id  metascore_num  \
# 0        1              1            1           43.2
# 1        2              1            2           48.5
# 2        3              1            2           80.0
# 3        4              1            6           80.0
# 4        5              1            7           69.3
# 5        6              2            1           80.0
# 6        7              2            3           93.9
# 7        8              2            4           80.0
# 8        9              2            4           80.0
# 9       10              2            7           80.0
#
#    copies_sold_millions_num categoria_ventas categoria_calidad  \
# 0                     23.52             Alto              Mala
# 1                      1.50            Medio              Mala
# 2                     30.00             Alto             Buena
# 3                      1.50            Medio             Buena
# 4                     14.78             Alto           Regular
# 5                     30.00             Alto             Buena
# 6                     32.51             Alto         Excelente
# 7                     30.00             Alto             Buena
# 8                     30.00             Alto             Buena
# 9                     30.00             Alto             Buena
#
#    num_juegos_plataforma  metascore_medio_plataforma  \
# 0                    342                       69.44
# 1                    375                       69.93
# 2                    375                       69.93
# 3                    312                       70.74
# 4                    323                       71.62
# 5                    342                       69.44
# 6                    325                       71.43
# 7                    349                       70.55
# 8                    349                       70.55
# 9                    323                       71.62
#
#    ventas_totales_plataforma
# 0                    6370.95
# 1                    7033.16
# 2                    7033.16
# 3                    5935.08
# 4                    6334.43
# 5                    6370.95
# 6                    6067.13
# 7                    7103.83
# 8                    7103.83
# 9                    6334.43
#
# ======================================================================
# CONSULTA JOIN - Análisis por género y plataforma
# ======================================================================
#          genre         platform  num_juegos  metascore_promedio  \
# 0       Sports  Nintendo Switch          47               65.93
# 1       action               pc          34               70.01
# 2      Unknown               pc          34               71.38
# 3      Unknown               PS          34               69.59
# 4       Puzzle               PS          35               68.79
# 5     Strategy               PC          30               70.47
# 6      Shooter          Switch           29               71.07
# 7        Indie               pc          33               70.09
# 8          RPG  Nintendo Switch          30               69.39
# 9        Indie      PlayStation          24               69.41
# 10           ?               PC          26               72.27
# 11  Simulation               PS          28               67.50
# 12      Racing  Nintendo Switch          32               70.88
# 13      Action           Mobile          29               72.36
# 14   Adventure          Switch           22               69.50
#
#     ventas_totales
# 0           760.19
# 1           748.45
# 2           725.15
# 3           724.49
# 4           691.70
# 5           652.19
# 6           649.03
# 7           648.87
# 8           643.88
# 9           642.88
# 10          628.77
# 11          619.44
# 12          607.90
# 13          606.13
# 14          603.39
#
# ✅ Verificación completada. Modelo dimensional funcionando correctamente.
# ✅ ETL con PySpark finalizado exitosamente.
